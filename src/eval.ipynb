# %%
from evaluation.Metrics import Metrics
from evaluation.Visualizer import Visualizer
from pathlib import Path 
import pandas as pd

# %%
metrics = []
for csv_path in Path("../results").glob("*.csv"):
    metric = Metrics(csv_path)
    metrics.append(metric)

    out_metrics_dir = Path("../results/metrics")
    out_metrics_dir.mkdir(parents=True, exist_ok=True)
    out_metrics_path = out_metrics_dir / f"{csv_path.stem}.csv"
    metric.metrics.to_csv(out_metrics_path)
   
    output_plot_dir = Path("../results/plots")
    output_plot_dir.mkdir(parents=True, exist_ok=True)
    output_plot_path = output_plot_dir / f"{csv_path.stem}.png"
    Visualizer.print_metrics_summary(metric.metrics, csv_path.stem, save_path=output_plot_path)

# %% [markdown]
# ## ShadowEnv=copy() VS ShadowEnv=llm

# %%
output_plot_dir = Path("../results/plots/aggregated")
output_plot_dir.mkdir(parents=True, exist_ok=True)

## Overall
#llmaction_true_metrics_overall = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'True'], name="LLM")
#llmaction_false_metrics_overall = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'False'], name="COPY")
#output_plot_path = output_plot_dir / f"ShadowEnv_Overall.png"
#Visualizer.print_aggregated_metrics_summary([llmaction_true_metrics_overall, llmaction_false_metrics_overall], "ShadowEnv: Overall", save_path=output_plot_path)

## With Lookahead
#llmaction_true_metrics_look = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'True' and int(m.metadata.get('lookaheadsize')) > 1], name="LLM")
#llmaction_false_metrics_look = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'False' and int(m.metadata.get('lookaheadsize')) > 1], name="COPY")
#output_plot_path = output_plot_dir / f"ShadowEnv_Lookahead.png"
#Visualizer.print_aggregated_metrics_summary([llmaction_true_metrics_look, llmaction_false_metrics_look], "ShadowEnv: Lookahead", save_path=output_plot_path)
#
## With no Lookahead
#llmaction_true_metrics_nolook = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'True' and int(m.metadata.get('lookaheadsize')) == 1], name="LLM") 
#llmaction_false_metrics_nolook = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'False' and int(m.metadata.get('lookaheadsize')) == 1], name="COPY")
#output_plot_path = output_plot_dir / f"ShadowEnv_NoLookahead.png"
#Visualizer.print_aggregated_metrics_summary([llmaction_true_metrics_nolook, llmaction_false_metrics_nolook], "ShadowEnv: No Lookahead", save_path=output_plot_path)

# All In One Plot - Average over everything
output_plot_path = output_plot_dir / f"ShadowEnv_AllInOne.png"
llmaction_true_metrics_overall = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'True'], name="LLM")
llmaction_false_metrics_overall = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'False'], name="COPY")
llmaction_true_metrics_look = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'True' and int(m.metadata.get('lookaheadsize')) > 1], name="LLM: Lookahead")
llmaction_false_metrics_look = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'False' and int(m.metadata.get('lookaheadsize')) > 1], name="COPY: Lookahead")
llmaction_true_metrics_nolook = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'True' and int(m.metadata.get('lookaheadsize')) == 1], name="LLM: No Lookahead") 
llmaction_false_metrics_nolook = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'False' and int(m.metadata.get('lookaheadsize')) == 1], name="COPY: No Lookahead")
Visualizer.print_aggregated_metrics_summary([llmaction_true_metrics_overall, llmaction_true_metrics_look, llmaction_true_metrics_nolook, llmaction_false_metrics_overall, llmaction_false_metrics_look, llmaction_false_metrics_nolook], "ShadowEnv: LLM vs COPY", save_path=output_plot_path)


# All in One Per Episode
output_plot_path = output_plot_dir / f"ShadowEnv_AllInOne_PerEpisode.png"
llmaction_true_overall_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('llmaction') == 'True'], name="LLM")
llmaction_false_overall_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('llmaction') == 'False'], name="COPY")
llmaction_true_look_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('llmaction') == 'True' and int(m.metadata.get('lookaheadsize')) > 1], name="LLM: Lookahead")
llmaction_false_look_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('llmaction') == 'False' and int(m.metadata.get('lookaheadsize')) > 1], name="COPY: Lookahead")
llmaction_true_nolook_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('llmaction') == 'True' and int(m.metadata.get('lookaheadsize')) == 1], name="LLM: No Lookahead") 
llmaction_false_nolook_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('llmaction') == 'False' and int(m.metadata.get('lookaheadsize')) == 1], name="COPY: No Lookahead")
Visualizer.print_aggregated_metrics_perepisode([llmaction_true_overall_perepisode, llmaction_true_look_perepisode, llmaction_true_nolook_perepisode, llmaction_false_overall_perepisode, llmaction_false_look_perepisode, llmaction_false_nolook_perepisode], "ShadowEnv: LLM vs COPY Per Episode", save_path=output_plot_path)
# LLM Per Episode
output_plot_path = output_plot_dir / f"ShadowEnv_LLM_PerEpisode.png"
Visualizer.print_aggregated_metrics_perepisode([llmaction_true_overall_perepisode, llmaction_true_look_perepisode, llmaction_true_nolook_perepisode,], "ShadowEnv: LLM Per Episode", save_path=output_plot_path)
# Copy Per Episode
output_plot_path = output_plot_dir / f"ShadowEnv_COPY_PerEpisode.png"
Visualizer.print_aggregated_metrics_perepisode([llmaction_false_overall_perepisode, llmaction_false_look_perepisode, llmaction_false_nolook_perepisode], "ShadowEnv: COPY Per Episode", save_path=output_plot_path)

# %% [markdown]
# ## Lookahead vs No Lookahead

# %%
output_plot_dir = Path("../results/plots/aggregated")
output_plot_dir.mkdir(parents=True, exist_ok=True)

## Overall
#lookahead_true_overall = Metrics.aggregate_metrics([m for m in metrics if int(m.metadata.get('lookaheadsize')) > 1], name="Lookahead")
#lookahead_false_overall = Metrics.aggregate_metrics([m for m in metrics if int(m.metadata.get('lookaheadsize')) == 1], name="No Lookahead")
#output_plot_path = output_plot_dir / f"Lookahead_Overall.png"
#Visualizer.print_aggregated_metrics_summary([lookahead_true_overall, lookahead_false_overall], "Lookahead: Overall", save_path=output_plot_path)
#
## With Lookahead
#lookahead_true_shadowllm = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'True' and int(m.metadata.get('lookaheadsize')) > 1], name="Lookahead")
#lookahead_false_shadowllm = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'True' and int(m.metadata.get('lookaheadsize')) == 1], name="No Lookahead")
#output_plot_path = output_plot_dir / f"Lookahead_ShadowLlm.png"
#Visualizer.print_aggregated_metrics_summary([lookahead_true_shadowllm, lookahead_false_shadowllm], "Lookahead: ShadowEnv via LLM", save_path=output_plot_path)
#
## With no Lookahead
#lookahead_true_shadowcopy = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'False' and int(m.metadata.get('lookaheadsize')) > 1], name="Lookahead")
#lookahead_false_shadowcopy = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'False' and int(m.metadata.get('lookaheadsize')) == 1], name="No Lookahead")
#output_plot_path = output_plot_dir / f"Lookahead_ShadowCopy.png"
#Visualizer.print_aggregated_metrics_summary([lookahead_true_shadowcopy, lookahead_false_shadowcopy], "Lookahead: ShadowEnv via Copy", save_path=output_plot_path)

# AllInOne - Average
output_plot_path = output_plot_dir / f"Lookahead_AllInOne.png"
lookahead_true_overall = Metrics.aggregate_metrics([m for m in metrics if int(m.metadata.get('lookaheadsize')) > 1], name="Lookahead")
lookahead_false_overall = Metrics.aggregate_metrics([m for m in metrics if int(m.metadata.get('lookaheadsize')) == 1], name="No Lookahead")
lookahead_true_shadowllm = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'True' and int(m.metadata.get('lookaheadsize')) > 1], name="Lookahead: ShadowEnv=LLM")
lookahead_false_shadowllm = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'True' and int(m.metadata.get('lookaheadsize')) == 1], name="No Lookahead: ShadowEnv=LLM")
lookahead_true_shadowcopy = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'False' and int(m.metadata.get('lookaheadsize')) > 1], name="Lookahead: ShadowEnv=COPY")
lookahead_false_shadowcopy = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('llmaction') == 'False' and int(m.metadata.get('lookaheadsize')) == 1], name="No Lookahead: ShadowEnv=COPY")
Visualizer.print_aggregated_metrics_summary([lookahead_true_overall, lookahead_true_shadowllm, lookahead_true_shadowcopy, lookahead_false_overall, lookahead_false_shadowllm, lookahead_false_shadowcopy], "Lookahead: Enabled vs Disabled", save_path=output_plot_path)

# AllInOnePerEpisode
output_plot_path = output_plot_dir / f"Lookahead_AllInOne_PerEpisode.png"
lookahead_true_overall_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if int(m.metadata.get('lookaheadsize')) > 1], name="Lookahead")
lookahead_false_overall_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if int(m.metadata.get('lookaheadsize')) == 1], name="No Lookahead")
lookahead_true_shadowllm_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('llmaction') == 'True' and int(m.metadata.get('lookaheadsize')) > 1], name="Lookahead: ShadowEnv=LLM")
lookahead_false_shadowllm_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('llmaction') == 'True' and int(m.metadata.get('lookaheadsize')) == 1], name="No Lookahead: ShadowEnv=LLM")
lookahead_true_shadowcopy_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('llmaction') == 'False' and int(m.metadata.get('lookaheadsize')) > 1], name="Lookahead: ShadowEnv=COPY")
lookahead_false_shadowcopy_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('llmaction') == 'False' and int(m.metadata.get('lookaheadsize')) == 1], name="No Lookahead: ShadowEnv=COPY")
Visualizer.print_aggregated_metrics_perepisode([lookahead_true_overall_perepisode, lookahead_true_shadowllm_perepisode, lookahead_true_shadowcopy_perepisode, lookahead_false_overall_perepisode, lookahead_false_shadowllm_perepisode, lookahead_false_shadowcopy_perepisode], "Lookahead: Enabled vs Disabled Per Episode", save_path=output_plot_path)
# Lookahed Per Episode
output_plot_path = output_plot_dir / f"Lookahead_Enabled_PerEpisode.png"
Visualizer.print_aggregated_metrics_perepisode([lookahead_true_overall_perepisode, lookahead_true_shadowllm_perepisode, lookahead_true_shadowcopy_perepisode], "Lookahead: Enabled Per Episode", save_path=output_plot_path)
output_plot_path = output_plot_dir / f"Lookahead_Disabled_PerEpisode.png"
Visualizer.print_aggregated_metrics_perepisode([lookahead_false_overall_perepisode, lookahead_false_shadowllm_perepisode, lookahead_false_shadowcopy_perepisode], "Lookahead: Disabled Per Episode", save_path=output_plot_path)

# %% [markdown]
# ## Maps: 4x4, 5x5, 6x6, 7x7, 8x8

# %%
output_plot_dir = Path("../results/plots/aggregated")
output_plot_dir.mkdir(parents=True, exist_ok=True)

# Overall
overall_4x4 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '4x4'], name="4x4")
overall_5x5 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '5x5'], name="5x5")
overall_6x6 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '6x6'], name="6x6")
overall_7x7 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '7x7'], name="7x7")
overall_8x8 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '8x8'], name="8x8")
output_plot_path = output_plot_dir / f"MapSize_Overall.png"
#Visualizer.print_aggregated_metrics_summary([overall_4x4, overall_5x5, overall_6x6, overall_7x7, overall_8x8], "Map Size: Overall", save_path=output_plot_path)

# Shadow LLM
shadowLlm_4x4 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '4x4' and m.metadata.get('llmaction') == 'True'], name="4x4 Map: LLM")
shadowLlm_5x5 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '5x5' and m.metadata.get('llmaction') == 'True'], name="5x5 Map: LLM")
shadowLlm_6x6 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '6x6' and m.metadata.get('llmaction') == 'True'], name="6x6 Map: LLM")
shadowLlm_7x7 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '7x7' and m.metadata.get('llmaction') == 'True'], name="7x7 Map: LLM")
shadowLlm_8x8 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '8x8' and m.metadata.get('llmaction') == 'True'], name="8x8 Map: LLM")
output_plot_path = output_plot_dir / f"MapSize_ShadowLlm.png"
#Visualizer.print_aggregated_metrics_summary([shadowLlm_4x4, shadowLlm_5x5, shadowLlm_6x6, shadowLlm_7x7, shadowLlm_8x8], "Map Size: Shadow LLM", save_path=output_plot_path)

# Shadow Copy
shadowCopy_4x4 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '4x4' and m.metadata.get('llmaction') == 'False'], name="4x4 Map: Copy")
shadowCopy_5x5 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '5x5' and m.metadata.get('llmaction') == 'False'], name="5x5 Map: Copy")
shadowCopy_6x6 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '6x6' and m.metadata.get('llmaction') == 'False'], name="6x6 Map: Copy")
shadowCopy_7x7 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '7x7' and m.metadata.get('llmaction') == 'False'], name="7x7 Map: Copy")
shadowCopy_8x8 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '8x8' and m.metadata.get('llmaction') == 'False'], name="8x8 Map: Copy")
output_plot_path = output_plot_dir / f"MapSize_ShadowCopy.png"
#Visualizer.print_aggregated_metrics_summary([shadowCopy_4x4, shadowCopy_5x5, shadowCopy_6x6, shadowCopy_7x7, shadowCopy_8x8], "Map Size: Shadow Copy", save_path=output_plot_path)

# Lookahead
lookahead_4x4 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '4x4' and int(m.metadata.get('lookaheadsize')) > 1], name="4x4 Map: Lookahead")
lookahead_5x5 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '5x5' and int(m.metadata.get('lookaheadsize')) > 1], name="5x5 Map: Lookahead")
lookahead_6x6 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '6x6' and int(m.metadata.get('lookaheadsize')) > 1], name="6x6 Map: Lookahead")
lookahead_7x7 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '7x7' and int(m.metadata.get('lookaheadsize')) > 1], name="7x7 Map: Lookahead")
lookahead_8x8 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '8x8' and int(m.metadata.get('lookaheadsize')) > 1], name="8x8 Map: Lookahead")
output_plot_path = output_plot_dir / f"MapSize_Lookahead.png"
#Visualizer.print_aggregated_metrics_summary([lookahead_4x4, lookahead_5x5, lookahead_6x6, lookahead_7x7, lookahead_8x8], "Map Size: Lookahead", save_path=output_plot_path)


# No Lookahead
nolookahead_4x4 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '4x4' and int(m.metadata.get('lookaheadsize')) == 1], name="4x4 Map: No Lookahead")
nolookahead_5x5 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '5x5' and int(m.metadata.get('lookaheadsize')) == 1], name="5x5 Map: No Lookahead")
nolookahead_6x6 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '6x6' and int(m.metadata.get('lookaheadsize')) == 1], name="6x6 Map: No Lookahead")
nolookahead_7x7 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '7x7' and int(m.metadata.get('lookaheadsize')) == 1], name="7x7 Map: No Lookahead")
nolookahead_8x8 = Metrics.aggregate_metrics([m for m in metrics if m.metadata.get('map_size') == '8x8' and int(m.metadata.get('lookaheadsize')) == 1], name="8x8 Map: No Lookahead")
output_plot_path = output_plot_dir / f"MapSize_NoLookahead.png"
#Visualizer.print_aggregated_metrics_summary([nolookahead_4x4, nolookahead_5x5, nolookahead_6x6, nolookahead_7x7, nolookahead_8x8], "Map Size: No Lookahead", save_path=output_plot_path)


# AllInOne Map Size Average
output_plot_path = output_plot_dir / f"Map_AllInOne.png"
Visualizer.print_aggregated_metrics_summary([overall_4x4, overall_5x5, overall_6x6, overall_7x7, overall_8x8], "Maps Overall", save_path=output_plot_path)
output_plot_path = output_plot_dir / f"Map_4x4.png"
Visualizer.print_aggregated_metrics_summary([overall_4x4, shadowLlm_4x4, shadowCopy_4x4, lookahead_4x4, nolookahead_4x4], "4x4 Map", save_path=output_plot_path)
output_plot_path = output_plot_dir / f"Map_5x5.png"
Visualizer.print_aggregated_metrics_summary([overall_5x5, shadowLlm_5x5, shadowCopy_5x5, lookahead_5x5, nolookahead_5x5], "5x5 Map", save_path=output_plot_path)
output_plot_path = output_plot_dir / f"Map_6x6.png"
Visualizer.print_aggregated_metrics_summary([overall_6x6, shadowLlm_6x6, shadowCopy_6x6, lookahead_6x6, nolookahead_6x6], "6x6 Map", save_path=output_plot_path)
output_plot_path = output_plot_dir / f"Map_7x7.png"
Visualizer.print_aggregated_metrics_summary([overall_7x7, shadowLlm_7x7, shadowCopy_7x7, lookahead_7x7, nolookahead_7x7], "7x7 Map", save_path=output_plot_path)
output_plot_path = output_plot_dir / f"Map_8x8.png"
Visualizer.print_aggregated_metrics_summary([overall_8x8, shadowLlm_8x8, shadowCopy_8x8, lookahead_8x8, nolookahead_8x8], "8x8 Map", save_path=output_plot_path)

# AllInOne per Episode
output_plot_path = output_plot_dir / f"MapSize_AllInOne_PerEpisode.png"
overall_4x4_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '4x4'], name="4x4")
overall_5x5_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '5x5'], name="5x5")
overall_6x6_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '6x6'], name="6x6")
overall_7x7_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '7x7'], name="7x7")
overall_8x8_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '8x8'], name="8x8")
Visualizer.print_aggregated_metrics_perepisode([overall_4x4_perepisode, overall_5x5_perepisode, overall_6x6_perepisode, overall_7x7_perepisode, overall_8x8_perepisode], "Maps Overall Per Episode", save_path=output_plot_path)

# 4x4 per Episode
output_plot_path = output_plot_dir / f"Map_4x4_PerEpisode.png"
overall_4x4_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '4x4'], name="4x4")
shadowLlm_4x4_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '4x4' and m.metadata.get('llmaction') == 'True'], name="4x4 Map: LLM")
shadowCopy_4x4_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '4x4' and m.metadata.get('llmaction') == 'False'], name="4x4 Map: Copy")
lookahead_4x4_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '4x4' and int(m.metadata.get('lookaheadsize')) > 1], name="4x4 Map: Lookahead")
nolookahead_4x4_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '4x4' and int(m.metadata.get('lookaheadsize')) == 1], name="4x4 Map: No Lookahead")
Visualizer.print_aggregated_metrics_perepisode([overall_4x4_perepisode, shadowLlm_4x4_perepisode, shadowCopy_4x4_perepisode, lookahead_4x4_perepisode, nolookahead_4x4_perepisode], "4x4 Map Per Episode", save_path=output_plot_path)

# 5x5 per Episode
output_plot_path = output_plot_dir / f"Map_5x5_PerEpisode.png"
overall_5x5_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '5x5'], name="5x5")
shadowLlm_5x5_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '5x5' and m.metadata.get('llmaction') == 'True'], name="5x5 Map: LLM")
shadowCopy_5x5_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '5x5' and m.metadata.get('llmaction') == 'False'], name="5x5 Map: Copy")
lookahead_5x5_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '5x5' and int(m.metadata.get('lookaheadsize')) > 1], name="5x5 Map: Lookahead")
nolookahead_5x5_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '5x5' and int(m.metadata.get('lookaheadsize')) == 1], name="5x5 Map: No Lookahead")
Visualizer.print_aggregated_metrics_perepisode([overall_5x5_perepisode, shadowLlm_5x5_perepisode, shadowCopy_5x5_perepisode, lookahead_5x5_perepisode, nolookahead_5x5_perepisode], "5x5 Map Per Episode", save_path=output_plot_path)

# 6x6 per Episode
output_plot_path = output_plot_dir / f"Map_6x6_PerEpisode.png"
overall_6x6_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '6x6'], name="6x6")
shadowLlm_6x6_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '6x6' and m.metadata.get('llmaction') == 'True'], name="6x6 Map: LLM")
shadowCopy_6x6_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '6x6' and m.metadata.get('llmaction') == 'False'], name="6x6 Map: Copy")
lookahead_6x6_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '6x6' and int(m.metadata.get('lookaheadsize')) > 1], name="6x6 Map: Lookahead")
nolookahead_6x6_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '6x6' and int(m.metadata.get('lookaheadsize')) == 1], name="6x6 Map: No Lookahead")
Visualizer.print_aggregated_metrics_perepisode([overall_6x6_perepisode, shadowLlm_6x6_perepisode, shadowCopy_6x6_perepisode, lookahead_6x6_perepisode, nolookahead_6x6_perepisode], "6x6 Map Per Episode", save_path=output_plot_path)

# 7x7 per Episode
output_plot_path = output_plot_dir / f"Map_7x7_PerEpisode.png"
overall_7x7_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '7x7'], name="7x7")
shadowLlm_7x7_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '7x7' and m.metadata.get('llmaction') == 'True'], name="7x7 Map: LLM")
shadowCopy_7x7_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '7x7' and m.metadata.get('llmaction') == 'False'], name="7x7 Map: Copy")
lookahead_7x7_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '7x7' and int(m.metadata.get('lookaheadsize')) > 1], name="7x7 Map: Lookahead")
nolookahead_7x7_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '7x7' and int(m.metadata.get('lookaheadsize')) == 1], name="7x7 Map: No Lookahead")
Visualizer.print_aggregated_metrics_perepisode([overall_7x7_perepisode, shadowLlm_7x7_perepisode, shadowCopy_7x7_perepisode, lookahead_7x7_perepisode, nolookahead_7x7_perepisode], "7x7 Map Per Episode", save_path=output_plot_path)

# 8x8 per Episode
output_plot_path = output_plot_dir / f"Map_8x8_PerEpisode.png"
overall_8x8_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '8x8'], name="8x8")
shadowLlm_8x8_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '8x8' and m.metadata.get('llmaction') == 'True'], name="8x8 Map: LLM")
shadowCopy_8x8_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '8x8' and m.metadata.get('llmaction') == 'False'], name="8x8 Map: Copy")
lookahead_8x8_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '8x8' and int(m.metadata.get('lookaheadsize')) > 1], name="8x8 Map: Lookahead")
nolookahead_8x8_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if m.metadata.get('map_size') == '8x8' and int(m.metadata.get('lookaheadsize')) == 1], name="8x8 Map: No Lookahead")
Visualizer.print_aggregated_metrics_perepisode([overall_8x8_perepisode, shadowLlm_8x8_perepisode, shadowCopy_8x8_perepisode, lookahead_8x8_perepisode, nolookahead_8x8_perepisode], "8x8 Map Per Episode", save_path=output_plot_path)

# %% [markdown]
# # Slippery vs Non Slippery

# %%
output_plot_dir = Path("../results/plots/aggregated")
output_plot_dir.mkdir(parents=True, exist_ok=True)

# Overall
slippery_true_overall = Metrics.aggregate_metrics([m for m in metrics if 'slippery' in m.metadata], name="Slippery")
slippery_false_overall = Metrics.aggregate_metrics([m for m in metrics if 'slippery' not in m.metadata], name="Not Slippery")

output_plot_path = output_plot_dir / f"Slippery_Overall.png"
#Visualizer.print_aggregated_metrics_summary([slippery_true_overall, slippery_false_overall], "Slippery vs Not Slippery", save_path=output_plot_path)

# ShadowEnv LLM
slippery_true_llmaction_true = Metrics.aggregate_metrics([m for m in metrics if 'slippery' in m.metadata and m.metadata.get('llmaction') == 'True'], name="Slippery: ShadowEnv=LLM")
slippery_false_llmaction_true = Metrics.aggregate_metrics([m for m in metrics if 'slippery' not in m.metadata and m.metadata.get('llmaction') == 'True'], name="Not Slippery: ShadowEnv=LLM")

# ShadowEnv Copy
slippery_true_llmaction_false = Metrics.aggregate_metrics([m for m in metrics if 'slippery' in m.metadata and m.metadata.get('llmaction') == 'False'], name="Slippery: ShadowEnv=COPY")
slippery_false_llmaction_false = Metrics.aggregate_metrics([m for m in metrics if 'slippery' not in m.metadata and m.metadata.get('llmaction') == 'False'], name="Not Slippery: ShadowEnv=COPY")

# With Lookahead
slippery_true_metrics_look = Metrics.aggregate_metrics([m for m in metrics if 'slippery' in m.metadata and int(m.metadata.get('lookaheadsize')) > 1], name="Slippery: Lookahead")
slippery_false_metrics_look = Metrics.aggregate_metrics([m for m in metrics if 'slippery' not in m.metadata and int(m.metadata.get('lookaheadsize')) > 1], name="Not Slippery: Lookahead")
output_plot_path = output_plot_dir / f"Slippery_Lookahead.png"
#Visualizer.print_aggregated_metrics_summary([slippery_true_metrics_look, slippery_false_metrics_look], "Slippery vs Not Slippery: Lookahead", save_path=output_plot_path)

# With no Lookahead
slippery_true_metrics_nolook = Metrics.aggregate_metrics([m for m in metrics if 'slippery' in m.metadata and int(m.metadata.get('lookaheadsize')) == 1], name="Slippery: No Lookahead") 
slippery_false_metrics_nolook = Metrics.aggregate_metrics([m for m in metrics if 'slippery' not in m.metadata and int(m.metadata.get('lookaheadsize')) == 1], name="Not Slippery: No Lookahead")
output_plot_path = output_plot_dir / f"Slippery_NoLookahead.png"
#Visualizer.print_aggregated_metrics_summary([slippery_true_metrics_nolook, slippery_false_metrics_nolook], "Slippery vs Not Slippery: No Lookahead", save_path=output_plot_path)

# All In One - Avg over eevrything
output_plot_path = output_plot_dir / f"Slippery_AllInOne.png"
Visualizer.print_aggregated_metrics_summary([slippery_true_overall, slippery_true_llmaction_true, slippery_true_llmaction_false, slippery_true_metrics_look, slippery_true_metrics_nolook,
                                             slippery_false_overall, slippery_false_llmaction_true, slippery_false_llmaction_false, slippery_false_metrics_look, slippery_false_metrics_nolook],
                                             "Slippery: Enabled vs Disabled", save_path=output_plot_path)

# Per Episode
output_plot_path = output_plot_dir / f"Slippery_AllInOne_PerEpisode.png"
slippery_true_overall_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if 'slippery' in m.metadata], name="Slippery")
slippery_false_overall_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if 'slippery' not in m.metadata], name="Not Slippery")
slippery_true_llmaction_true_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if 'slippery' in m.metadata and m.metadata.get('llmaction') == 'True'], name="Slippery: ShadowEnv=LLM")
slippery_false_llmaction_true_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if 'slippery' not in m.metadata and m.metadata.get('llmaction') == 'True'], name="Not Slippery: ShadowEnv=LLM")
slippery_true_llmaction_false_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if 'slippery' in m.metadata and m.metadata.get('llmaction') == 'False'], name="Slippery: ShadowEnv=COPY")
slippery_false_llmaction_false_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if 'slippery' not in m.metadata and m.metadata.get('llmaction') == 'False'], name="Not Slippery: ShadowEnv=COPY")
slippery_true_metrics_look_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if 'slippery' in m.metadata and int(m.metadata.get('lookaheadsize')) > 1], name="Slippery: Lookahead")
slippery_false_metrics_look_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if 'slippery' not in m.metadata and int(m.metadata.get('lookaheadsize')) > 1], name="Not Slippery: Lookahead")
slippery_true_metrics_nolook_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if 'slippery' in m.metadata and int(m.metadata.get('lookaheadsize')) == 1], name="Slippery: No Lookahead") 
slippery_false_metrics_nolook_perepisode = Metrics.aggregate_metrics_perepisode([m for m in metrics if 'slippery' not in m.metadata and int(m.metadata.get('lookaheadsize')) == 1], name="Not Slippery: No Lookahead")

Visualizer.print_aggregated_metrics_perepisode([slippery_true_overall_perepisode, slippery_true_llmaction_true_perepisode, slippery_true_llmaction_false_perepisode, slippery_true_metrics_look_perepisode, slippery_true_metrics_nolook_perepisode,
                                                slippery_false_overall_perepisode, slippery_false_llmaction_true_perepisode, slippery_false_llmaction_false_perepisode, slippery_false_metrics_look_perepisode, slippery_false_metrics_nolook_perepisode],
                                               "Slippery: Enabled vs Disabled", save_path=output_plot_path)
# Divide it
output_plot_dir = output_plot_dir / f"Slippery_Enabled_PerEpisode.png"
Visualizer.print_aggregated_metrics_perepisode([slippery_true_overall_perepisode, slippery_true_llmaction_true_perepisode, slippery_true_llmaction_false_perepisode, slippery_true_metrics_look_perepisode, slippery_true_metrics_nolook_perepisode],
                                               "Slippery: Enabled Per Episode", save_path=output_plot_path)
output_plot_dir = output_plot_dir / f"Slippery_Dsiabled_PerEpisode.png"
Visualizer.print_aggregated_metrics_perepisode([slippery_false_overall_perepisode, slippery_false_llmaction_true_perepisode, slippery_false_llmaction_false_perepisode, slippery_false_metrics_look_perepisode, slippery_false_metrics_nolook_perepisode],
                                               "Slippery: Disabled Per Episode", save_path=output_plot_path)

# %%
output_plot_dir = Path("../results/plots/aggregated")
output_plot_dir.mkdir(parents=True, exist_ok=True)

# Create empty template dictionaries
template_1 = {
    'benchmark_name': 'Template_name_1',
    'total_episodes': 67,
    'overall_success_rate': 0.8,
    'avg_steps': 13,
    'avg_steps_successful': 16,
    'avg_total_reward': 6,
    'avg_reward_per_step': 0.46,
    'termination_counts': {"error": 67, "goal": 6},
}
template_2 = {
    'benchmark_name': 'Template_name_2',
    'total_episodes': 42,
    'overall_success_rate': 0.9,
    'avg_steps': 42,
    'avg_steps_successful': 49,
    'avg_total_reward': 7,
    'avg_reward_per_step': 0.14285714285714285,
    'termination_counts': {"error": 19, "goal": 23},
}

# ShadowEnv template
shadowenv_templates = [
    {**template_1, 'benchmark_name': 'Template 1'},
    {**template_2, 'benchmark_name': 'Template 2'}
]
output_plot_path = output_plot_dir / f"TEMPLATE.png"
Visualizer.print_aggregated_metrics_summary(shadowenv_templates, "Template", save_path=output_plot_path)


template = pd.read_csv("../results/template/TEMPLATE.csv")
output_plot_dir = Path("../results/plots")
output_plot_dir.mkdir(parents=True, exist_ok=True)
output_plot_path = output_plot_dir / f"Template.png"
Visualizer.print_metrics_summary(template, "Template", save_path=output_plot_path)
