# %%
from navigation.Navigator import Navigator
from navigation.environments.FrozenLakeEnv import FrozenLakeEnv
from navigation.environments.FrozenLakeShadowEnv import FrozenLakeShadowEnv

from tinydb import TinyDB
from openai import OpenAI
import os

import gymnasium as gym

# %%
hypothesesDb = TinyDB("../store/frozenlake/hypotheses.json")
policyDb = TinyDB("../store/frozenlake/policies.json")

client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key= os.getenv("OPENROUTER_API_KEY")
) 
model = "openai/gpt-oss-120b"

# %%
env = FrozenLakeEnv(env = gym.make("FrozenLake-v1", render_mode="ansi",  desc=None, map_name="4x4", is_slippery=False, success_rate=1.0/3.0, reward_schedule=(1, 0, 0)))
shadow_env = FrozenLakeShadowEnv(hypothesesDb, policyDb, client, model)

navigator = Navigator(environment=env, shadow_env=shadow_env)

navigator.run(sample_size=2, depth=3, use_llm_action=False, debug=True)
# Out:
# Sample 1, Step 1: Executed Move: move_right, Value: 72
# New State:
#  S [F] F  F
#  F  H  F  H
#  F  F  F  H
#  H  F  F  G
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 6
#       2 shadow_env = FrozenLakeShadowEnv(hypothesesDb, policyDb, client, model)
#       4 navigator = Navigator(environment=env, shadow_env=shadow_env)
# ----> 6 navigator.run(sample_size=2, depth=3, use_llm_action=False, debug=True)
#
# File ~/dev/curated-agent-architecture/src/navigation/Navigator.py:26, in Navigator.run(self, sample_size, depth, use_llm_action, debug)
#      23 state = self.environment.get_state() # maybe return one string reprsenting that state, and the actual env state
#      24 trajectory += f"Current State:\n{state}\n\n"
# ...
